# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\shukl\AppData\Local\Temp\ipykernel_15236\2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
dataframe1 = pd.read_csv('C:/Users/shukl/Downloads/insurance.csv')

# %%
dataframe1
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
dataframe1.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
dataframe1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
dataframe1['family_count']= dataframe1['children']+1

# %%
dataframe1['family_count']
# Out:
# 0       1
# 1       2
# 2       4
# 3       1
# 4       1
#        ..
# 1333    4
# 1334    1
# 1335    1
# 1336    1
# 1337    1
# Name: family_count, Length: 1338, dtype: int64

# %%
dataframe1['avg_exp_per_head']= dataframe1['expenses']/dataframe1['family_count']

# %%
dataframe1['avg_exp_per_head']
# Out:
# 0       16884.9200
# 1         862.7750
# 2        1112.3650
# 3       21984.4700
# 4        3866.8600
#            ...
# 1333     2650.1375
# 1334     2205.9800
# 1335     1629.8300
# 1336     2007.9500
# 1337    29141.3600
# Name: avg_exp_per_head, Length: 1338, dtype: float64

# %%
dataframe2=dataframe1.drop('children',axis= 1)

# %%
dataframe2.drop('bmi', axis=1,inplace= True)

# %%
dataframe2
# Out:
#       age     sex smoker     region  expenses  family_count  avg_exp_per_head
# 0      19  female    yes  southwest  16884.92             1        16884.9200
# 1      18    male     no  southeast   1725.55             2          862.7750
# 2      28    male     no  southeast   4449.46             4         1112.3650
# 3      33    male     no  northwest  21984.47             1        21984.4700
# 4      32    male     no  northwest   3866.86             1         3866.8600
# ...   ...     ...    ...        ...       ...           ...               ...
# 1333   50    male     no  northwest  10600.55             4         2650.1375
# 1334   18  female     no  northeast   2205.98             1         2205.9800
# 1335   18  female     no  southeast   1629.83             1         1629.8300
# 1336   21  female     no  southwest   2007.95             1         2007.9500
# 1337   61  female    yes  northwest  29141.36             1        29141.3600
#
# [1338 rows x 7 columns]

# %%
#Ordering in Ascending or Decending
dataframe2.sort_values(by='avg_exp_per_head',axis= 0,ascending=False)
# Out:
#       age     sex smoker     region  expenses  family_count  avg_exp_per_head
# 543    54  female    yes  southeast  63770.43             1      63770.430000
# 1300   45    male    yes  southeast  62592.87             1      62592.870000
# 819    33  female    yes  northwest  55135.40             1      55135.400000
# 1146   60    male    yes  southwest  52590.83             1      52590.830000
# 488    44  female    yes  southeast  48885.14             1      48885.140000
# ...   ...     ...    ...        ...       ...           ...               ...
# 413    25    male     no  southwest   5080.10             6        846.683333
# 984    20    male     no  northeast   4915.06             6        819.176667
# 166    20  female     no  southwest   4830.63             6        805.105000
# 32     19  female     no  southwest   4687.80             6        781.300000
# 938    18    male     no  southeast   2304.00             3        768.000000
#
# [1338 rows x 7 columns]

# %%
dataframe2.sort_values(by=['age','avg_exp_per_head'],axis= 0,ascending=[False, False])
# Out:
#       age     sex smoker     region  expenses  family_count  avg_exp_per_head
# 420    64    male    yes  southeast  46889.26             1         46889.260
# 890    64  female    yes  northwest  29330.98             1         29330.980
# 664    64  female    yes  southeast  27037.91             1         27037.910
# 1265   64    male    yes  southeast  26926.51             1         26926.510
# 328    64  female    yes  southwest  47928.03             2         23964.015
# ...   ...     ...    ...        ...       ...           ...               ...
# 1      18    male     no  southeast   1725.55             2           862.775
# 1283   18    male     no  southeast   1720.35             2           860.175
# 270    18    male     no  southeast   1719.44             2           859.720
# 1023   18    male     no  southeast   1711.03             2           855.515
# 938    18    male     no  southeast   2304.00             3           768.000
#
# [1338 rows x 7 columns]

# %%
dataframe1.sort_index()
# Out:
#       age     sex   bmi  children smoker     region  expenses  family_count  \
# 0      19  female  27.9         0    yes  southwest  16884.92             1
# 1      18    male  33.8         1     no  southeast   1725.55             2
# 2      28    male  33.0         3     no  southeast   4449.46             4
# 3      33    male  22.7         0     no  northwest  21984.47             1
# 4      32    male  28.9         0     no  northwest   3866.86             1
# ...   ...     ...   ...       ...    ...        ...       ...           ...
# 1333   50    male  31.0         3     no  northwest  10600.55             4
# 1334   18  female  31.9         0     no  northeast   2205.98             1
# 1335   18  female  36.9         0     no  southeast   1629.83             1
# 1336   21  female  25.8         0     no  southwest   2007.95             1
# 1337   61  female  29.1         0    yes  northwest  29141.36             1
#
#       avg_exp_per_head
# 0           16884.9200
# ...

# %%
dataframe1['age'].min(), dataframe1['age'].max()
# Out:
# (18, 64)

# %%
dataframe1.groupby('age')['avg_exp_per_head'].agg(['mean','count','max','min','std','count'])
# Out:
#              mean  count        max          min           std  count
# age
# 18    5844.538594     69  38792.690   768.000000   9520.074546     69
# 19    8318.573725     68  39722.750   781.300000  11855.634963     68
# 20    6715.886092     29  33475.820   805.105000   8516.566620     29
# 21    2721.650696     28  16586.500   965.302500   3251.111162     28
# 22    6206.272262     28  35585.580   860.765000   9623.579993     28
# 23    7159.838393     28  34166.270   897.870000   8245.868070     28
# 24    9612.090244     28  38126.250  1058.732500  12412.526039     28
# 25    5525.646417     28  33900.650   846.683333   7361.834999     28
# 26    3107.508494     28  17043.340  1161.443333   3451.487700     28
# 27    8868.835536     28  39611.760  1065.185000  11408.063733     28
# 28    5352.318899     28  34672.150   935.895000   8075.055315     28
# 29    6020.556877     27  36197.700  1141.774000   7627.704122     27
# ...

# %%
dataframe1
# Out:
#       age     sex   bmi  children smoker     region  expenses  family_count  \
# 0      19  female  27.9         0    yes  southwest  16884.92             1
# 1      18    male  33.8         1     no  southeast   1725.55             2
# 2      28    male  33.0         3     no  southeast   4449.46             4
# 3      33    male  22.7         0     no  northwest  21984.47             1
# 4      32    male  28.9         0     no  northwest   3866.86             1
# ...   ...     ...   ...       ...    ...        ...       ...           ...
# 1333   50    male  31.0         3     no  northwest  10600.55             4
# 1334   18  female  31.9         0     no  northeast   2205.98             1
# 1335   18  female  36.9         0     no  southeast   1629.83             1
# 1336   21  female  25.8         0     no  southwest   2007.95             1
# 1337   61  female  29.1         0    yes  northwest  29141.36             1
#
#       avg_exp_per_head
# 0           16884.9200
# ...

# %%
def age_grp(age):
    if age<=23:
        return 'Student'
    elif (age>23) and (age<50):
        return 'Adult'
    else:
        return 'Aged'

# %%
#Using Funtion to every row
dataframe1['age_group']= dataframe1['age'].apply(age_grp)

# %%
dataframe1
# Out:
#       age     sex   bmi  children smoker     region  expenses  family_count  \
# 0      19  female  27.9         0    yes  southwest  16884.92             1
# 1      18    male  33.8         1     no  southeast   1725.55             2
# 2      28    male  33.0         3     no  southeast   4449.46             4
# 3      33    male  22.7         0     no  northwest  21984.47             1
# 4      32    male  28.9         0     no  northwest   3866.86             1
# ...   ...     ...   ...       ...    ...        ...       ...           ...
# 1333   50    male  31.0         3     no  northwest  10600.55             4
# 1334   18  female  31.9         0     no  northeast   2205.98             1
# 1335   18  female  36.9         0     no  southeast   1629.83             1
# 1336   21  female  25.8         0     no  southwest   2007.95             1
# 1337   61  female  29.1         0    yes  northwest  29141.36             1
#
#       avg_exp_per_head age_group
# ...

# %%
dataframe1['age_group'].value_counts()
# Out:
# age_group
# Adult      703
# Aged       385
# Student    250
# Name: count, dtype: int64

# %%
dataframe1.drop_duplicates(inplace= True)

# %%
dataframe1.isnull()
# Out:
#         age    sex    bmi  children  smoker  region  expenses  family_count  \
# 0     False  False  False     False   False   False     False         False
# 1     False  False  False     False   False   False     False         False
# 2     False  False  False     False   False   False     False         False
# 3     False  False  False     False   False   False     False         False
# 4     False  False  False     False   False   False     False         False
# ...     ...    ...    ...       ...     ...     ...       ...           ...
# 1333  False  False  False     False   False   False     False         False
# 1334  False  False  False     False   False   False     False         False
# 1335  False  False  False     False   False   False     False         False
# 1336  False  False  False     False   False   False     False         False
# 1337  False  False  False     False   False   False     False         False
#
#       avg_exp_per_head  age_group
# ...

# %%
dataframe1.isnull().sum()
# Out:
# age                 0
# sex                 0
# bmi                 0
# children            0
# smoker              0
# region              0
# expenses            0
# family_count        0
# avg_exp_per_head    0
# age_group           0
# dtype: int64

# %%
boll=dataframe1['age']==19

# %%
dataframe19=dataframe1.loc[boll,:]

# %%
dataframe19
# Out:
#       age     sex   bmi  children smoker     region  expenses  family_count  \
# 0      19  female  27.9         0    yes  southwest  16884.92             1
# 15     19    male  24.6         1     no  southwest   1837.24             2
# 32     19  female  28.6         5     no  southwest   4687.80             6
# 35     19    male  20.4         0     no  northwest   1625.43             1
# 65     19  female  28.9         0     no  southwest   1743.21             1
# ...   ...     ...   ...       ...    ...        ...       ...           ...
# 1251   19    male  19.8         0     no  southwest   1241.57             1
# 1291   19    male  34.9         0    yes  southwest  34828.65             1
# 1299   19  female  25.7         1     no  northwest   2710.83             2
# 1313   19  female  34.7         2    yes  southwest  36397.58             3
# 1316   19  female  20.6         0     no  southwest   1731.68             1
#
#       avg_exp_per_head age_group
# ...

# %%
dataframe20=dataframe1.loc[dataframe1['age']==20]

# %%
dataframe20
# Out:
#       age     sex   bmi  children smoker     region  expenses  family_count  \
# 64     20  female  22.4         0    yes  northwest  14711.74             1
# 105    20    male  28.0         1    yes  northwest  17560.38             2
# 122    20  female  29.0         0     no  northwest   2257.48             1
# 134    20  female  28.8         0     no  northeast   2457.21             1
# 166    20  female  37.0         5     no  southwest   4830.63             6
# 210    20    male  33.0         1     no  southwest   1980.07             2
# 261    20  female  26.8         1    yes  southeast  17085.27             2
# 374    20    male  33.3         0     no  southeast   1391.53             1
# 453    20    male  29.7         0     no  northwest   1769.53             1
# 495    20    male  27.9         0     no  northeast   1967.02             1
# 516    20    male  35.3         1     no  southeast  27724.29             2
# ...

# %%
dataframe19.shape
# Out:
# (67, 10)

# %%
dataframe20.shape
# Out:
# (29, 10)
