# %%
import pandas as pd
# Out:
# C:\Users\shukl\AppData\Local\Temp\ipykernel_14496\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
li= [1,2,3,4,5]

# %%
type(li)
# Out:
# list

# %%
ser=pd.Series(li)

# %%
ser
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
dfram=pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]], columns=['A','B','C'],index=['a','b','c'])
dfram
# Out:
#    A  B  C
# a  1  2  3
# b  4  5  6
# c  7  8  9

# %%
dict1={'A':[1,2,3],
       'B':[4,5,6],
       'C':[7,8,9]}

# %%
dfram2=pd.DataFrame(dict1)

# %%
dict1
# Out:
# {'A': [1, 2, 3], 'B': [4, 5, 6], 'C': [7, 8, 9]}

# %%
type(dict1)
# Out:
# dict

# %%
dfram2
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
dataframe3 = pd.read_excel(r'C:\Users\shukl\Downloads\IMDB_DataSheet.xlsx')

# %%
dataframe3
# Out:
#              director_name  num_critic_for_reviews  duration      gross  \
# 0           Frank Darabont                     199       142   28341469
# 1     Francis Ford Coppola                     208       175  134821952
# 2        Christopher Nolan                     645       152  533316061
# 3     Francis Ford Coppola                     149       220   57300000
# 4            Peter Jackson                     328       192  377019252
# ...                    ...                     ...       ...        ...
# 3717    Vondie Curtis-Hall                      66       104    4273372
# 3718      Don Michael Paul                      25        93    5694308
# 3719       Jason Friedberg                     111        88   14174654
# 3720             Bob Clark                      32        88    9109322
# 3721            Jon M. Chu                      84       115   73000942
#
#                               genres    actor_1_name  \
# ...

# %%
dataframe3.shape
# Out:
# (3722, 33)

# %%
dataframe3.dtypes
# Out:
# director_name              object
# num_critic_for_reviews      int64
# duration                    int64
# gross                       int64
# genres                     object
# actor_1_name               object
# movie_title                object
# num_voted_users             int64
# num_user_for_reviews        int64
# language                   object
# country                    object
# budget                      int64
# title_year                  int64
# imdb_score                float64
# Profit                      int64
# Unnamed: 15               float64
# Unnamed: 16               float64
# Unnamed: 17               float64
# Unique Directors           object
# Median of Duration        float64
# Median of Imdscore        float64
# Average                   float64
# Percentile                float64
# Unnamed: 23               float64
# Unnamed: 24               float64
# Unnamed: 25               float64
# Unnamed: 26               float64
# ...

# %%
dataframe3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3722 entries, 0 to 3721
# Data columns (total 33 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   director_name           3722 non-null   object
#  1   num_critic_for_reviews  3722 non-null   int64
#  2   duration                3722 non-null   int64
#  3   gross                   3722 non-null   int64
#  4   genres                  3722 non-null   object
#  5   actor_1_name            3722 non-null   object
#  6   movie_title             3722 non-null   object
#  7   num_voted_users         3722 non-null   int64
#  8   num_user_for_reviews    3722 non-null   int64
#  9   language                3721 non-null   object
#  10  country                 3722 non-null   object
#  11  budget                  3722 non-null   int64
#  12  title_year              3722 non-null   int64
#  13  imdb_score              3722 non-null   float64
# ...

# %%
#Positional
dataframe3.iloc[0:5, :]
# Out:
#           director_name  num_critic_for_reviews  duration      gross  \
# 0        Frank Darabont                     199       142   28341469
# 1  Francis Ford Coppola                     208       175  134821952
# 2     Christopher Nolan                     645       152  533316061
# 3  Francis Ford Coppola                     149       220   57300000
# 4         Peter Jackson                     328       192  377019252
#
#                            genres    actor_1_name  \
# 0                     Crime|Drama  Morgan Freeman
# 1                     Crime|Drama       Al Pacino
# 2     Action|Crime|Drama|Thriller  Christian Bale
# 3                     Crime|Drama  Robert De Niro
# 4  Action|Adventure|Drama|Fantasy   Orlando Bloom
#
#                                        movie_title  num_voted_users  \
# 0                       The Shawshank RedemptionÂ           1689764
# 1                                  The GodfatherÂ           1155770
# ...

# %%
#Column Name
dataframe3.loc[:5,'director_name':'gross']
# Out:
#           director_name  num_critic_for_reviews  duration      gross
# 0        Frank Darabont                     199       142   28341469
# 1  Francis Ford Coppola                     208       175  134821952
# 2     Christopher Nolan                     645       152  533316061
# 3  Francis Ford Coppola                     149       220   57300000
# 4         Peter Jackson                     328       192  377019252
# 5     Quentin Tarantino                     215       178  107930000
